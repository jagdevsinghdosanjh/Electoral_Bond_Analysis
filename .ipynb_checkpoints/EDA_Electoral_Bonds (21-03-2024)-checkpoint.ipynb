# %% [markdown]
# ## Exploratory Data Analysis-Electoral Bonds (Jagdev Singh Dosanjh)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
company = pd.read_csv("EB_Purchaser_Detail.csv")
party = pd.read_csv("EB_Redemption_Details.csv")

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19256 entries, 0 to 19255
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr No.                 19256 non-null  object
#  1   Reference No  (URN)    19256 non-null  object
#  2   Journal Date           19256 non-null  object
# Purchase       19256 non-null  object
#  4   Date of Expiry         19256 non-null  object
#  5   Name of the Purchaser  19256 non-null  object
#  6   Prefix                 19256 non-null  object
# Number            19256 non-null  object
#  8   Denominations          19256 non-null  object
#  9   Issue Branch Code      19256 non-null  object
#  10  Issue Teller           19256 non-null  object
#  11  Status                 19256 non-null  object
# dtypes: object(12)
# memory usage: 1.8+ MB

# %%
party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20972 entries, 0 to 20971
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Sr No.                          20972 non-null  object
# Encashment              20972 non-null  object
#  2   Name of the Political Party     20972 non-null  object
# Political Party  20972 non-null  object
#  4   Prefix                          20972 non-null  object
# Number                     20972 non-null  object
#  6   Denominations                   20972 non-null  object
# Code                 20972 non-null  object
#  8   Pay Teller                      20972 non-null  object
# dtypes: object(9)
# memory usage: 1.4+ MB

# %%
company.columns
# Out:
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\rPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Prefix', 'Bond\rNumber',
#        'Denominations', 'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
party.columns
# Out:
# Index(['Sr No.', 'Date of\rEncashment', 'Name of the Political Party',
#        'Account no. of\rPolitical Party', 'Prefix', 'Bond\rNumber',
#        'Denominations', 'Pay Branch\rCode', 'Pay Teller'],
#       dtype='object')

# %%
company
# Out:
#       Sr No.      Reference No  (URN) Journal Date Date of\rPurchase  \
# 0          1  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 1          2  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 2          3  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 3          4  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 4          5  00001201904120000001166  12/Apr/2019       12/Apr/2019
# ...      ...                      ...          ...               ...
# 19251  18867  00001202401110000003729  11/Jan/2024       11/Jan/2024
# 19252  18868  00001202401110000003729  11/Jan/2024       11/Jan/2024
# 19253  18869  00001202401110000003729  11/Jan/2024       11/Jan/2024
# 19254  18870  00001202401110000003729  11/Jan/2024       11/Jan/2024
# 19255  18871  00001202401110000003729  11/Jan/2024       11/Jan/2024
#
#       Date of Expiry           Name of the Purchaser Prefix Bond\rNumber  \
# ...

# %%
party
# Out:
#       Sr No. Date of\rEncashment               Name of the Political Party  \
# 0          1         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1          2         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2          3         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3          4         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4          5         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...      ...                 ...                                       ...
# 20967  20417         24/Jan/2024                            JANASENA PARTY
# 20968  20418         24/Jan/2024                            JANASENA PARTY
# 20969  20419         24/Jan/2024                            JANASENA PARTY
# 20970  20420         24/Jan/2024                            JANASENA PARTY
# 20971  20421         24/Jan/2024                            JANASENA PARTY
#
# ...

# %%
company.shape
# Out:
# (19256, 12)

# %%
party.shape
# Out:
# (20972, 9)
